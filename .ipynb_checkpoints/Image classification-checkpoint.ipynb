# %%
import tensorflow as tf

# %%
import numpy as np

# %%
filename= 'Training data//chef.jpg'

# %%
from IPython.display import Image
Image(filename= 'Training data//chef.jpg',width=224,height=224)

# %%
mobile=tf.keras.applications.mobilenet.MobileNet() ##loading deep learning model
# Out:
# ...
# 17227776/17225924 [==============================] - 8s 0us/step
